# %% [markdown]
# <a href="https://colab.research.google.com/github/LukaKaric/Domaci/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv("diabetes_risk_prediction_dataset.csv")
data.head(15)
# Out:
#     Age Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0    40   Male       No        Yes                 No      Yes         No
# 1    58   Male       No         No                 No      Yes         No
# 2    41   Male      Yes         No                 No      Yes        Yes
# 3    45   Male       No         No                Yes      Yes        Yes
# 4    60   Male      Yes        Yes                Yes      Yes        Yes
# 5    55   Male      Yes        Yes                 No      Yes        Yes
# 6    57   Male      Yes        Yes                 No      Yes        Yes
# 7    66   Male      Yes        Yes                Yes      Yes         No
# 8    67   Male      Yes        Yes                 No      Yes        Yes
# 9    70   Male       No        Yes                Yes      Yes        Yes
# 10   44   Male      Yes        Yes                 No      Yes         No
# 11   38   Male      Yes        Yes                 No       No        Yes
# 12   35   Male      Yes         No                 No       No        Yes
# 13   61   Male      Yes        Yes                Yes      Yes        Yes
# 14   60   Male      Yes        Yes                 No      Yes        Yes
#
#    Genital thrush visual blurring Itching Irritability delayed healing  \
# 0              No              No     Yes           No             Yes
# 1              No             Yes      No           No              No
# 2              No              No     Yes           No             Yes
# 3             Yes              No     Yes           No             Yes
# 4              No             Yes     Yes          Yes             Yes
# 5              No             Yes     Yes           No             Yes
# 6             Yes              No      No           No             Yes
# 7              No             Yes     Yes          Yes              No
# 8             Yes              No     Yes          Yes              No
# 9              No             Yes     Yes          Yes              No
# 10            Yes              No      No          Yes             Yes
# 11            Yes              No     Yes           No             Yes
# 12            Yes              No      No          Yes             Yes
# 13            Yes             Yes     Yes           No              No
# 14             No             Yes     Yes           No             Yes
#
#    partial paresis muscle stiffness Alopecia Obesity     class
# 0               No              Yes      Yes     Yes  Positive
# 1              Yes               No      Yes      No  Positive
# 2               No              Yes      Yes      No  Positive
# 3               No               No       No      No  Positive
# 4              Yes              Yes      Yes     Yes  Positive
# 5               No              Yes      Yes     Yes  Positive
# 6              Yes               No       No      No  Positive
# 7              Yes              Yes       No      No  Positive
# 8              Yes              Yes       No     Yes  Positive
# 9               No               No      Yes      No  Positive
# 10              No              Yes      Yes      No  Positive
# 11              No              Yes       No      No  Positive
# 12              No               No      Yes      No  Positive
# 13              No               No      Yes     Yes  Positive
# 14             Yes               No       No      No  Positive

# %%
sns.scatterplot(data, x = data['Age'],y = data['class'])
plt.show()

sns.scatterplot(data, x = data['Gender'],y = data['class'])
plt.show()

sns.scatterplot(data, x = data['Polyuria'],y = data['class'])
plt.show()

sns.scatterplot(data, x = data['Polydipsia'],y = data['class'])
plt.show()

sns.scatterplot(data, x = data['sudden weight loss'],y = data['class'])
plt.show()

sns.scatterplot(data, x = data['weakness'],y = data['class'])
plt.show()

sns.scatterplot(data, x = data['sudden weight loss'],y = data['class'])
plt.show()

sns.scatterplot(data, x = data['Polyphagia'],y = data['class'])
plt.show()

sns.scatterplot(data, x = data['Genital thrush'],y = data['class'])
plt.show()

sns.scatterplot(data, x = data['visual blurring'],y = data['class'])
plt.show()

sns.scatterplot(data, x = data['Itching'],y = data['class'])
plt.show()

sns.scatterplot(data, x = data['Irritability'],y = data['class'])
plt.show()

sns.scatterplot(data, x = data['delayed healing'],y = data['class'])
plt.show()

sns.scatterplot(data, x = data['partial paresis'],y = data['class'])
plt.show()

sns.scatterplot(data, x = data['muscle stiffness'],y = data['class'])
plt.show()

sns.scatterplot(data, x = data['Alopecia'],y = data['class'])
plt.show()

sns.scatterplot(data, x = data['Obesity'],y = data['class'])
plt.show()

# %%
data = data.replace('Yes', 1)
data = data.replace('No', 0)
data = data.replace('Male', 1)
data = data.replace('Female', 0)
data = data.replace('Positive', 1)
data = data.replace('Negative', 0)

# %%
import numpy as np
import seaborn as sns


cor = data.corr().iloc[-1].sort_values(ascending=True)
display(cor)
# Out:
# Gender               -0.449233
# Alopecia             -0.267512
# Itching              -0.013384
# delayed healing       0.046980
# Obesity               0.072173
# Age                   0.108679
# Genital thrush        0.110288
# muscle stiffness      0.122474
# weakness              0.243275
# visual blurring       0.251300
# Irritability          0.299467
# Polyphagia            0.342504
# partial paresis       0.432288
# sudden weight loss    0.436568
# Polydipsia            0.648734
# Polyuria              0.665922
# class                 1.000000
# Name: class, dtype: float64

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(data, test_size=0.2)

print(len(train))
print(len(test))
# Out:
# 416
# 104

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(train[['Age']], train['class'])
# Out:
# LogisticRegression()
